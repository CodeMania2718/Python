# %%
pwd
# Out:
# 'C:\\ana\\aio_cloud\\samsung_eda'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/filtered_memory_5_ips.csv',parse_dates=['ingestion_time'])

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'ingestion_time', 'metric_id', 'value', 'timestamp',
#        'ip', 'port'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'id',],axis=1,inplace=True)
df.sort_values(by='ingestion_time',inplace=True)
df.set_index('ingestion_time',inplace=True,drop=False)

# %%
print(df['ip'].nunique())
df['ip'].unique()
# Out:
# 5
# array(['10.80.99.159', '10.80.98.115', '10.80.51.40', '10.80.80.36',
#        '10.80.102.24'], dtype=object)

# %%
df
# Out:
#                                                    ingestion_time metric_id  \
# ingestion_time
# 2023-05-09 00:04:35.598155+00:00 2023-05-09 00:04:35.598155+00:00   s_pr_02
# 2023-05-09 00:04:35.598155+00:00 2023-05-09 00:04:35.598155+00:00   s_pr_02
# 2023-05-09 00:04:35.598155+00:00 2023-05-09 00:04:35.598155+00:00   s_pr_02
# 2023-05-09 00:04:35.598155+00:00 2023-05-09 00:04:35.598155+00:00   s_pr_02
# 2023-05-09 00:04:35.598155+00:00 2023-05-09 00:04:35.598155+00:00   s_pr_02
# ...                                                           ...       ...
# 2023-05-12 06:48:35.393571+00:00 2023-05-12 06:48:35.393571+00:00   s_pr_02
# 2023-05-12 06:48:35.393571+00:00 2023-05-12 06:48:35.393571+00:00   s_pr_02
# 2023-05-12 06:48:35.393571+00:00 2023-05-12 06:48:35.393571+00:00   s_pr_02
# 2023-05-12 06:48:35.393571+00:00 2023-05-12 06:48:35.393571+00:00   s_pr_02
# 2023-05-12 06:48:35.393571+00:00 2023-05-12 06:48:35.393571+00:00   s_pr_02
#
#                                      value                  timestamp  \
# ingestion_time
# 2023-05-09 00:04:35.598155+00:00  0.849018  2023-05-09 00:01:35+00:00
# 2023-05-09 00:04:35.598155+00:00  0.158489  2023-05-09 00:01:35+00:00
# 2023-05-09 00:04:35.598155+00:00  0.646230  2023-05-09 00:01:35+00:00
# 2023-05-09 00:04:35.598155+00:00  0.161926  2023-05-09 00:01:35+00:00
# 2023-05-09 00:04:35.598155+00:00  0.734127  2023-05-09 00:01:35+00:00
# ...                                    ...                        ...
# 2023-05-12 06:48:35.393571+00:00  0.647209  2023-05-12 06:45:35+00:00
# 2023-05-12 06:48:35.393571+00:00  0.164321  2023-05-12 06:45:35+00:00
# 2023-05-12 06:48:35.393571+00:00  0.850732  2023-05-12 06:45:35+00:00
# 2023-05-12 06:48:35.393571+00:00  0.735258  2023-05-12 06:45:35+00:00
# 2023-05-12 06:48:35.393571+00:00  0.164766  2023-05-12 06:45:35+00:00
#
#                                             ip  port
# ingestion_time
# 2023-05-09 00:04:35.598155+00:00  10.80.99.159  9100
# 2023-05-09 00:04:35.598155+00:00  10.80.98.115  9100
# 2023-05-09 00:04:35.598155+00:00   10.80.51.40  9100
# 2023-05-09 00:04:35.598155+00:00   10.80.80.36  9100
# 2023-05-09 00:04:35.598155+00:00  10.80.102.24  9100
# ...                                        ...   ...
# 2023-05-12 06:48:35.393571+00:00   10.80.51.40  9100
# 2023-05-12 06:48:35.393571+00:00   10.80.80.36  9100
# 2023-05-12 06:48:35.393571+00:00  10.80.99.159  9100
# 2023-05-12 06:48:35.393571+00:00  10.80.102.24  9100
# 2023-05-12 06:48:35.393571+00:00  10.80.98.115  9100
#
# [11815 rows x 6 columns]

# %%
df[df['ip']=='10.80.80.36'].ingestion_time.diff()
# Out:
# ingestion_time
# 2023-05-09 00:04:35.598155+00:00                      NaT
# 2023-05-09 00:06:35.490725+00:00   0 days 00:01:59.892570
# 2023-05-09 00:08:35.482507+00:00   0 days 00:01:59.991782
# 2023-05-09 00:10:35.491313+00:00   0 days 00:02:00.008806
# 2023-05-09 00:12:35.387552+00:00   0 days 00:01:59.896239
#                                             ...
# 2023-05-12 06:40:35.776434+00:00   0 days 00:02:00.289209
# 2023-05-12 06:42:35.395346+00:00   0 days 00:01:59.618912
# 2023-05-12 06:44:35.377900+00:00   0 days 00:01:59.982554
# 2023-05-12 06:46:35.480319+00:00   0 days 00:02:00.102419
# 2023-05-12 06:48:35.393571+00:00   0 days 00:01:59.913252
# Name: ingestion_time, Length: 2363, dtype: timedelta64[ns]

# %%
 df.index.min(),df.index.max(),df.index.max()-df.index.min()
# Out:
# (Timestamp('2023-05-09 00:04:35.598155+0000', tz='UTC'),
#  Timestamp('2023-05-12 06:48:35.393571+0000', tz='UTC'),
#  Timedelta('3 days 06:43:59.795416'))

# %%
df['value'].describe()
# Out:
# count    11815.000000
# mean         0.511119
# std          0.292342
# min          0.157218
# 25%          0.162597
# 50%          0.646799
# 75%          0.735066
# max          0.851220
# Name: value, dtype: float64

# %%
start_time='2023-05-09 00:04:35'
end_time='2023-05-09 01:04:35'
df1=df.loc[(df.index >= start_time) & (df.index < end_time)]

# df1['value']=df1['value']*100
vms=df['ip'].unique()
df1[df1['ip']==vms[0]]['value'].plot(grid=True,figsize=(30,9))
# Out:
# <AxesSubplot:xlabel='ingestion_time'>

# %%
df1[df1['ip']==vms[1]]['value'].plot(grid=True,figsize=(30,9))
# Out:
# <AxesSubplot:xlabel='ingestion_time'>

# %%
df1.groupby('ip')['value'].plot(grid=True,figsize=(30,9))
plt.legend(loc='upper right')
plt.show()

# %%
df.loc['2023-05-09'].groupby('ip')['value'].plot(grid=True,figsize=(30,9))
plt.legend(loc='upper right')
plt.show()

# %%
df.loc['2023-05-10'].groupby('ip')['value'].plot(grid=True,figsize=(30,9))
plt.legend(loc='upper right')
plt.show()

# %%
df.loc['2023-05-11'].groupby('ip')['value'].plot(grid=True,figsize=(30,9))
plt.legend(loc='upper right')
plt.show()
